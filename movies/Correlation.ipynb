# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
#selecting filename var

filename =("movies.csv")

# %%
df =pd.read_csv(filename)

# %%
# checking the shape of the data, no of rows & no of cols

df.shape
# Out:
# (7668, 15)

# %%
# Now let's take a look at the data

df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# checking for nulls

df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
# checking for missing data

# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#looking at data types 
# Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# checkinfor values at the cell is null

df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
#Aggregating all the null vaules in each col

df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# dropping null values

df =df.dropna()
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# cheking for null values again 

df.isnull().sum().sum()
# Out:
# 0

# %%
    #converting data types 
    
df['budget'] =df['budget'].astype('int64')
    
df['gross'] =df['gross'].astype('int64')

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
#pulling from relaesed data to New column

# %%
df.released
# Out:
# 0           June 13, 1980 (United States)
# 1            July 2, 1980 (United States)
# 2           June 20, 1980 (United States)
# 3            July 2, 1980 (United States)
# 4           July 25, 1980 (United States)
#                       ...
# 7648     January 17, 2020 (United States)
# 7649    February 14, 2020 (United States)
# 7650     January 17, 2020 (United States)
# 7651    February 21, 2020 (United States)
# 7652      August 28, 2020 (United States)
# Name: released, Length: 5421, dtype: object

# %%
#to remove white space

df.columns=df.columns.str.strip()

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                               gross
# company                             year
# "DIA" Productions GmbH & Co. KG     2003   44350926
# "Weathering With You" Film Partners 2019  193457467
# .406 Production                     1996      10580
# 1492 Pictures                       1996  129832389
#                                     1999   87423861
# ...                                             ...
# erbp                                2013     587174
# i am OTHER                          2015   17986781
# i5 Films                            2001   10031529
# micro_scope                         2010    7099598
# thefyzz                             2017   62198461
#
# [2987 rows x 1 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Warner Bros.           2005    2688767210
# Name: gross, dtype: int64

# %%
# spliting by delimeter

df["released"].str.split(',')
# Out:
# 0           [June 13,  1980 (United States)]
# 1            [July 2,  1980 (United States)]
# 2           [June 20,  1980 (United States)]
# 3            [July 2,  1980 (United States)]
# 4           [July 25,  1980 (United States)]
#                         ...
# 7648     [January 17,  2020 (United States)]
# 7649    [February 14,  2020 (United States)]
# 7650     [January 17,  2020 (United States)]
# 7651    [February 21,  2020 (United States)]
# 7652      [August 28,  2020 (United States)]
# Name: released, Length: 5421, dtype: object

# %%
df["released"].str.split(',',n=1)
# Out:
# 0           [June 13,  1980 (United States)]
# 1            [July 2,  1980 (United States)]
# 2           [June 20,  1980 (United States)]
# 3            [July 2,  1980 (United States)]
# 4           [July 25,  1980 (United States)]
#                         ...
# 7648     [January 17,  2020 (United States)]
# 7649    [February 14,  2020 (United States)]
# 7650     [January 17,  2020 (United States)]
# 7651    [February 21,  2020 (United States)]
# 7652      [August 28,  2020 (United States)]
# Name: released, Length: 5421, dtype: object

# %%
#adding the splitted column to a temporary data frame


release_new=df["released"].str.split(',',n=1,expand=True)
release_new.rename(columns={0:"first",1:"Last"})
# Out:
#             first                   Last
# 0         June 13   1980 (United States)
# 1          July 2   1980 (United States)
# 2         June 20   1980 (United States)
# 3          July 2   1980 (United States)
# 4         July 25   1980 (United States)
# ...           ...                    ...
# 7648   January 17   2020 (United States)
# 7649  February 14   2020 (United States)
# 7650   January 17   2020 (United States)
# 7651  February 21   2020 (United States)
# 7652    August 28   2020 (United States)
#
# [5421 rows x 2 columns]

# %%
#adding the splitted collums to the main data frame

df[["first","last"]] =df["released"].str.split(',',n=1,expand=True)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df["correctyear"]=df["last"].astype(str).str[:5]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# sorting by gross column
df=df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
#to drop duplicate in a column
#df['compnay']=df['compnay'].drop_duplicate()


#to drop all duplicate
#df.drop.duplicate().sort_values(ascending=False)

#or
#df.drop_duplicate()










# checking for correlation

# %%
#scatter plot with burdget gross reveune 
plt.scatter(x=df['budget'],y=df['gross'])

plt.title('Budget vs GrossEarings')

plt.xlabel('Gross earnings')

plt.ylabel('Budget for film')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# regression plot for  budget vs gross using seaborn
sns.regplot(x='budget', y='gross', data=df , scatter_kws={"color":"blue"}, line_kws={"color":"red"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#There are different type of correlations--method must be either 'pearson', 'spearman', 'kendall', or a callab
# start looking at the correlation -- This will only pull numeric values(high correlation betwwen budget and growth)
df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# the above data is called correlation_matrix
correlation_matrix = df.corr(method='pearson')
plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

sns.heatmap(correlation_matrix, annot=True)
plt.show()

#brighter colors higher correlation and vice versa

# %%
# converting company to numeric and creating a numeric representaion of the string using for loop

# %%
df_numerized=df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype =='object'):
       df_numerized[col_name] = df_numerized[col_name].astype('category')
       df_numerized[col_name] = df_numerized[col_name].cat.codes
                                
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
# correaltion metrix for data frame numerized 
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_matrix =df_numerized.corr()

corr_paris=correlation_matrix.unstack()
corr_paris
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# correctyear  company       -0.022510
#              runtime        0.073115
#              first         -0.010885
#              last           0.959713
#              correctyear    1.000000
# Length: 324, dtype: float64

# %%
sorted_pairs =corr_paris.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
#                               ...
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# writer       writer         1.000000
# correctyear  correctyear    1.000000
# Length: 324, dtype: float64

# %%
high_corr= sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# correctyear  last           0.959713
# last         correctyear    0.959713
#              year           0.971972
# year         last           0.971972
#              correctyear    0.987770
# correctyear  year           0.987770
# released     first          0.999839
# first        released       0.999839
# name         name           1.000000
# first        first          1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# last         last           1.000000
# director     director       1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# ...

# %%
#votes and budgets have the highest correlation to gross earinings

# in general company as low correlation

# %%
# Are there any Outliers?-- the point or points that are farthest from the regression line.

df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
#regression plot for score vs gross using seaborn


sns.regplot(x="score", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='score', ylabel='gross'>

# %%
# Correlation Matrix between all numeric columns

df.corr(method ='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
df.corr(method ='kendall')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.017023  0.005970  0.018614 -0.004104  0.005372
# rating      -0.017023  1.000000  0.137396 -0.015490  0.023547  0.067313
# genre        0.005970  0.137396  1.000000 -0.058976  0.016088  0.045217
# year         0.018614 -0.015490 -0.058976  1.000000 -0.001054  0.039389
# released    -0.004104  0.023547  0.016088 -0.001054  1.000000  0.028223
# score        0.005372  0.067313  0.045217  0.039389  0.028223  1.000000
# votes        0.002477 -0.008994 -0.133391  0.296512  0.005205  0.350185
# director     0.010060  0.005950 -0.005585 -0.025293  0.001886  0.009176
# writer       0.008769  0.001735  0.011042 -0.018691  0.005302  0.009058
# star        -0.004706  0.014913  0.002258 -0.022272  0.010118  0.004414
# country     -0.020738 -0.010547 -0.012696 -0.057292 -0.016524 -0.100231
# budget       0.014275 -0.208389 -0.275983  0.220833 -0.000030 -0.006406
# ...

# %%
df.corr(method ='spearman')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.021980  0.008213  0.027766 -0.006341  0.007866
# rating      -0.021980  1.000000  0.167778 -0.018206  0.031301  0.085237
# genre        0.008213  0.167778  1.000000 -0.080105  0.022254  0.061615
# year         0.027766 -0.018206 -0.080105  1.000000 -0.002404  0.057741
# released    -0.006341  0.031301  0.022254 -0.002404  1.000000  0.042145
# score        0.007866  0.085237  0.061615  0.057741  0.042145  1.000000
# votes        0.003615 -0.011871 -0.182682  0.427623  0.006280  0.495409
# director     0.014933  0.007809 -0.007466 -0.037591  0.002797  0.013366
# writer       0.013023  0.002124  0.015393 -0.027646  0.007941  0.013441
# star        -0.007027  0.019408  0.003449 -0.032760  0.015392  0.006735
# country     -0.026431 -0.011824 -0.015225 -0.072272 -0.021012 -0.124916
# budget       0.021395 -0.267486 -0.372729  0.312886 -0.000495 -0.009971
# ...

# %%
#correlation Math

correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name         name           1.000000
#              rating         0.314800
#              genre          0.186668
#              year           0.267282
#              released       0.667785
#                               ...
# correctyear  company        0.140530
#              runtime        0.037692
#              first         -0.019707
#              last           0.279341
#              correctyear    1.000000
# Length: 324, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# rating       score         -0.075109
# score        rating        -0.075109
#              country       -0.057087
# country      score         -0.057087
#              genre         -0.055109
#                               ...
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# writer       writer         1.000000
# correctyear  correctyear    1.000000
# Length: 324, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# director     star           0.504992
# star         director       0.504992
# writer       star           0.510628
# star         writer         0.510628
# votes        writer         0.522918
#                               ...
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# writer       writer         1.000000
# correctyear  correctyear    1.000000
# Length: 66, dtype: float64

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# 1426    54610959970
# 1397    51241105418
# 452     42356430218
# 1108    40021704691
# 1382    39542573303
# 1423    35833650748
# 1044    19612851164
# 983     15065592411
# 550     11873612858
# 551     11593807697
# 1367    10664679494
# 1001     8937010092
# 1309     8318570396
# 1134     7886344526
# 682      7243673721
# Name: gross, dtype: int64

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                   gross
# company year
# 0       2003   44350926
# 1       2019  193457467
# 2       1996      10580
# 3       1996  129832389
#         1999   87423861
# ...                 ...
# 1470    2013     587174
# 1471    2015   17986781
# 1472    2001   10031529
# 1473    2010    7099598
# 1474    2017   62198461
#
# [2987 rows x 1 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company  year
# 1423     2019    5773131804
# 983      2018    4018631866
# 1397     2015    3834354888
# 1382     2009    3793491246
# 1423     2017    3789382071
# 1108     2011    3565705182
# 1426     2011    3223799224
# 1423     2010    3104474158
# 1108     2014    3071298586
# 452      2006    2934631933
#          2019    2932757449
# 983      2019    2797501328
# 1426     2018    2774168962
# 452      2011    2738363306
# 1426     2005    2688767210
# Name: gross, dtype: int64

# %%
# THE END = CORRELATION CONFIRMED
